# %%
import pandas as pd
import numpy as np
import requests
import warnings
from dotenv import load_dotenv
from datetime import datetime
import os
import json
from pandas.errors import SettingWithCopyWarning

load_dotenv()
warnings.simplefilter("ignore", SettingWithCopyWarning)

# %%
landslides = pd.read_excel("../Datasets/Colombia Lansdslides Table.xlsx")

display(landslides.info())
landslides
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2266 entries, 0 to 2265
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Occurrence Date        2266 non-null   datetime64[ns]
#  1   Department             2266 non-null   object
#  2   Municipality           2266 non-null   object
#  3   Lat                    2266 non-null   object
#  4   Long                   2266 non-null   object
#  5   Confidence ratio (km)  2266 non-null   object
#  6   Deaths                 2266 non-null   int64
#  7   Trigger                2266 non-null   object
#  8   Source                 2266 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 159.5+ KB
# None
#      Occurrence Date       Department      Municipality   Lat   Long  \
# 0         1934-05-30        ANTIOQUIA          ABRIAQUI  6.63 -76.09
# 1         1934-09-29           BOGOTA            BOGOTA  4.63 -74.11
# 2         1934-11-18           CALDAS         CHINCHINA  4.97 -75.66
# 3         1934-11-28  VALLE DEL CAUCA              CALI   3.4 -76.58
# 4         1934-11-29          QUINDIO           ARMENIA   4.5 -75.73
# ...              ...              ...               ...   ...    ...
# 2261      2020-12-01          BOLIVAR  BARRANCO DE LOBA  8.84 -74.28
# 2262      2020-12-03        RISARALDA           PEREIRA   4.8  -75.8
# 2263      2020-12-12        ANTIOQUIA          SAN LUIS     6 -75.05
# 2264      2020-12-15        ANTIOQUIA          MEDELLIN  6.25 -75.58
# 2265      2020-12-25        ANTIOQUIA            ITAGUI  6.18 -75.61
#
#      Confidence ratio (km)  Deaths         Trigger               Source
# 0                     9.65       5        Rainfall                 CNMM
# 1                     11.6       2  Human activity                  HEB
# 2                     5.92       1         Unknown                 CNMM
# 3                    13.44       2         Unknown                 CNMM
# 4                     6.17       1         Unknown          DESINVENTAR
# ...                    ...     ...             ...                  ...
# 2261                 11.68       3  Human activity  News Report - UNGRD
# 2262                 13.91       1         Unknown                UNGRD
# 2263                   0.1       2         Unknown          News Report
# 2264                   6.5       2  Human activity          News Report
# 2265                  2.53       2      Earthquake  News Report - UNGRD
#
# [2266 rows x 9 columns]

# %%
landslides.sort_values(["Lat", "Long"])
# Out:
#      Occurrence Date    Department          Municipality   Lat   Long  \
# 641       1972-07-26      PUTUMAYO           PUERTO ASIS  0.43 -76.52
# 338       1962-08-16        NARIÑO               IPIALES   0.5 -77.24
# 1125      1988-04-22        NARIÑO               IPIALES   0.5 -77.24
# 1165      1988-12-03        NARIÑO               IPIALES   0.5 -77.24
# 1284      1994-08-03        NARIÑO               IPIALES   0.5 -77.24
# ...              ...           ...                   ...   ...    ...
# 1445      2000-04-19        NARIÑO               UNKNOWN     -      -
# 1454      2000-07-02     ANTIOQUIA               UNKNOWN     -      -
# 1455      2000-08-18        NARIÑO               UNKNOWN     -      -
# 1513      2004-03-05  CUNDINAMARCA               UNKNOWN     -      -
# 1749      2009-05-25         CHOCO  LITORAL DEL SAN JUAN     -      -
#
#      Confidence ratio (km)  Deaths         Trigger               Source
# 641                  29.96       4         Unknown  CTM96 - DESINVENTAR
# 338                  22.45      14         Unknown                 CNMM
# 1125                 22.45      29         Unknown                 CNMM
# 1165                 22.45      15        Rainfall          DESINVENTAR
# 1284                 22.45       2         Unknown          DESINVENTAR
# ...                    ...     ...             ...                  ...
# 1445                     -       1        Rainfall          DESINVENTAR
# 1454                     -       1        Rainfall          DESINVENTAR
# 1455                     -       9  Human activity          DESINVENTAR
# 1513                     -       1        Rainfall          DESINVENTAR
# 1749                     -       1         Unknown                UNGRD
#
# [2266 rows x 9 columns]

# %%
landslides = landslides[landslides["Lat"] != "-"]
landslides[["Lat", "Long", "Confidence ratio (km)"]] = landslides[["Lat", "Long", "Confidence ratio (km)"]].astype(float)

display(landslides.info())
landslides
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2240 entries, 0 to 2265
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Occurrence Date        2240 non-null   datetime64[ns]
#  1   Department             2240 non-null   object
#  2   Municipality           2240 non-null   object
#  3   Lat                    2240 non-null   float64
#  4   Long                   2240 non-null   float64
#  5   Confidence ratio (km)  2240 non-null   float64
#  6   Deaths                 2240 non-null   int64
#  7   Trigger                2240 non-null   object
#  8   Source                 2240 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 175.0+ KB
# None
#      Occurrence Date       Department      Municipality   Lat   Long  \
# 0         1934-05-30        ANTIOQUIA          ABRIAQUI  6.63 -76.09
# 1         1934-09-29           BOGOTA            BOGOTA  4.63 -74.11
# 2         1934-11-18           CALDAS         CHINCHINA  4.97 -75.66
# 3         1934-11-28  VALLE DEL CAUCA              CALI  3.40 -76.58
# 4         1934-11-29          QUINDIO           ARMENIA  4.50 -75.73
# ...              ...              ...               ...   ...    ...
# 2261      2020-12-01          BOLIVAR  BARRANCO DE LOBA  8.84 -74.28
# 2262      2020-12-03        RISARALDA           PEREIRA  4.80 -75.80
# 2263      2020-12-12        ANTIOQUIA          SAN LUIS  6.00 -75.05
# 2264      2020-12-15        ANTIOQUIA          MEDELLIN  6.25 -75.58
# 2265      2020-12-25        ANTIOQUIA            ITAGUI  6.18 -75.61
#
#       Confidence ratio (km)  Deaths         Trigger               Source
# 0                      9.65       5        Rainfall                 CNMM
# 1                     11.60       2  Human activity                  HEB
# 2                      5.92       1         Unknown                 CNMM
# 3                     13.44       2         Unknown                 CNMM
# 4                      6.17       1         Unknown          DESINVENTAR
# ...                     ...     ...             ...                  ...
# 2261                  11.68       3  Human activity  News Report - UNGRD
# 2262                  13.91       1         Unknown                UNGRD
# 2263                   0.10       2         Unknown          News Report
# 2264                   6.50       2  Human activity          News Report
# 2265                   2.53       2      Earthquake  News Report - UNGRD
#
# [2240 rows x 9 columns]

# %%
landslides.describe()
# Out:
#                      Occurrence Date          Lat         Long  \
# count                           2240  2240.000000  2240.000000
# mean   1987-08-02 23:06:38.571428480     5.118714   -75.272795
# min              1934-05-30 00:00:00     0.430000   -78.600000
# 25%              1971-04-20 18:00:00     4.410000   -75.860000
# 50%              1988-09-17 00:00:00     5.070000   -75.510000
# 75%              2008-11-03 18:00:00     6.260000   -74.947500
# max              2020-12-25 00:00:00    12.000000    75.750000
# std                              NaN     1.890475     3.391700
#
#        Confidence ratio (km)        Deaths
# count            2240.000000   2240.000000
# mean               10.713237     16.127679
# min                 0.100000      1.000000
# 25%                 6.170000      1.000000
# 50%                 9.460000      2.000000
# 75%                13.430000      4.000000
# max                74.660000  21697.000000
# std                 7.528650    460.265346

# %%
landslides["Long"] = landslides["Long"].apply(lambda x: x if x <= 0 else -1 * x)

landslides.describe()
# Out:
#                      Occurrence Date          Lat         Long  \
# count                           2240  2240.000000  2240.000000
# mean   1987-08-02 23:06:38.571428480     5.118714   -75.340429
# min              1934-05-30 00:00:00     0.430000   -78.600000
# 25%              1971-04-20 18:00:00     4.410000   -75.860000
# 50%              1988-09-17 00:00:00     5.070000   -75.510000
# 75%              2008-11-03 18:00:00     6.260000   -74.950000
# max              2020-12-25 00:00:00    12.000000   -68.010000
# std                              NaN     1.890475     1.145650
#
#        Confidence ratio (km)        Deaths
# count            2240.000000   2240.000000
# mean               10.713237     16.127679
# min                 0.100000      1.000000
# 25%                 6.170000      1.000000
# 50%                 9.460000      2.000000
# 75%                13.430000      4.000000
# max                74.660000  21697.000000
# std                 7.528650    460.265346

# %%
landslides_recent = landslides[landslides["Occurrence Date"].dt.year >= 2010].reset_index(drop = True)

landslides_recent
# Out:
#     Occurrence Date       Department      Municipality   Lat   Long  \
# 0        2010-01-10           BOGOTA            BOGOTA  4.63 -74.11
# 1        2010-02-25     CUNDINAMARCA           VILLETA  5.01 -74.49
# 2        2010-04-10           TOLIMA            HERVEO  5.11 -75.19
# 3        2010-04-10  VALLE DEL CAUCA              CALI  3.40 -76.58
# 4        2010-04-29           BOGOTA            BOGOTA  4.63 -74.11
# ..              ...              ...               ...   ...    ...
# 499      2020-12-01          BOLIVAR  BARRANCO DE LOBA  8.84 -74.28
# 500      2020-12-03        RISARALDA           PEREIRA  4.80 -75.80
# 501      2020-12-12        ANTIOQUIA          SAN LUIS  6.00 -75.05
# 502      2020-12-15        ANTIOQUIA          MEDELLIN  6.25 -75.58
# 503      2020-12-25        ANTIOQUIA            ITAGUI  6.18 -75.61
#
#      Confidence ratio (km)  Deaths         Trigger               Source
# 0                    11.60       1         Unknown                  HEB
# 1                     6.70       1        Rainfall                UNGRD
# 2                     1.52       1         Unknown                UNGRD
# 3                    13.44       1         Unknown                UNGRD
# 4                    11.60       1         Unknown                UNGRD
# ..                     ...     ...             ...                  ...
# 499                  11.68       3  Human activity  News Report - UNGRD
# 500                  13.91       1         Unknown                UNGRD
# 501                   0.10       2         Unknown          News Report
# 502                   6.50       2  Human activity          News Report
# 503                   2.53       2      Earthquake  News Report - UNGRD
#
# [504 rows x 9 columns]

# %%
rain_yesterday = []
rain_today = []

for i, row in landslides_recent.iterrows():
    start_date = (row["Occurrence Date"] + pd.Timedelta(days=-1)).strftime("%Y-%m-%d")
    end_date = row["Occurrence Date"].strftime("%Y-%m-%d")

    endpoint = "{}/timeline/{},{}/{}/{}".format(
        os.environ.get("WEATHER_URL"),
        row["Lat"],
        row["Long"],
        start_date,
        end_date
    )
    
    params = {
        "unitGroup": "metric",
        "key": os.environ.get("WEATHER_API_KEY")
    }
    
    response = requests.get(endpoint, params)
    result = json.loads(response.text)
    
    rain_yesterday.append(result["days"][0]["precip"])
    rain_today.append(result["days"][1]["precip"])
    
landslides_recent["Rain Yesterday"] = rain_yesterday
landslides_recent["Rain Today"] = rain_today

display(landslides_recent.describe())
landslides_recent
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 21
#       8 endpoint = "{}/timeline/{},{}/{}/{}".format(
#       9     os.environ.get("WEATHER_URL"),
#      10     row["Lat"],
#    (...)
#      13     end_date
#      14 )
#      16 params = {
#      17     "unitGroup": "metric",
#      18     "key": os.environ.get("WEATHER_API_KEY")
#      19 }
# ---> 21 response = requests.get(endpoint, params)
#      22 result = json.loads(response.text)
#      24 rain_yesterday.append(result["days"][0]["precip"])
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/mlenv/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
landslides_recent.to_csv("../datasets/landslides_rainfall.csv", index = False, quoting = False)

# %%
landslides_recent = pd.read_csv("../Datasets/landslides_rainfall.csv")
landslides_recent["Occurrence Date"] = pd.to_datetime(landslides_recent["Occurrence Date"])

display(landslides_recent.describe())
landslides_recent
# Out:
#                      Occurrence Date         Lat        Long  \
# count                            504  504.000000  504.000000
# mean   2014-11-17 09:14:17.142857216    5.009067  -75.277083
# min              2010-01-10 00:00:00    0.500000  -78.370000
# 25%              2011-09-19 18:00:00    3.132500  -76.145000
# 50%              2014-05-10 00:00:00    5.185000  -75.510000
# 75%              2017-12-05 12:00:00    6.440000  -74.325000
# max              2020-12-25 00:00:00   11.250000  -68.010000
# std                              NaN    2.203510    1.414380
#
#        Confidence ratio (km)      Deaths  Rain Yesterday  Rain Today
# count             504.000000  504.000000      504.000000  504.000000
# mean                9.658313    3.430556        8.609921    8.698810
# min                 0.100000    1.000000        0.000000    0.000000
# 25%                 4.452500    1.000000        1.300000    1.600000
# 50%                 7.850000    1.000000        5.100000    5.300000
# 75%                12.575000    3.000000       11.825000   11.600000
# max                73.090000  333.000000       88.100000   89.100000
# std                 8.442951   16.055295       11.012548   10.544394
#     Occurrence Date       Department      Municipality   Lat   Long  \
# 0        2010-01-10           BOGOTA            BOGOTA  4.63 -74.11
# 1        2010-02-25     CUNDINAMARCA           VILLETA  5.01 -74.49
# 2        2010-04-10           TOLIMA            HERVEO  5.11 -75.19
# 3        2010-04-10  VALLE DEL CAUCA              CALI  3.40 -76.58
# 4        2010-04-29           BOGOTA            BOGOTA  4.63 -74.11
# ..              ...              ...               ...   ...    ...
# 499      2020-12-01          BOLIVAR  BARRANCO DE LOBA  8.84 -74.28
# 500      2020-12-03        RISARALDA           PEREIRA  4.80 -75.80
# 501      2020-12-12        ANTIOQUIA          SAN LUIS  6.00 -75.05
# 502      2020-12-15        ANTIOQUIA          MEDELLIN  6.25 -75.58
# 503      2020-12-25        ANTIOQUIA            ITAGUI  6.18 -75.61
#
#      Confidence ratio (km)  Deaths         Trigger               Source  \
# 0                    11.60       1         Unknown                  HEB
# 1                     6.70       1        Rainfall                UNGRD
# 2                     1.52       1         Unknown                UNGRD
# 3                    13.44       1         Unknown                UNGRD
# 4                    11.60       1         Unknown                UNGRD
# ..                     ...     ...             ...                  ...
# 499                  11.68       3  Human activity  News Report - UNGRD
# 500                  13.91       1         Unknown                UNGRD
# 501                   0.10       2         Unknown          News Report
# 502                   6.50       2  Human activity          News Report
# 503                   2.53       2      Earthquake  News Report - UNGRD
#
#      Rain Yesterday  Rain Today
# 0               0.0         0.0
# 1               2.2         9.7
# 2               4.9        18.0
# 3              10.1        23.1
# 4               4.4        16.3
# ..              ...         ...
# 499             0.0         0.0
# 500             2.6         8.2
# 501             0.0         0.0
# 502             0.0         0.0
# 503             0.0         0.0
#
# [504 rows x 11 columns]

# %%
random_sample = landslides_recent.sample(len(landslides_recent), replace = True, random_state = 1326)
random_sample
# Out:
#     Occurrence Date Department  Municipality   Lat   Long  \
# 252      2014-05-11      HUILA         SUAZA  1.94 -75.80
# 257      2014-09-09     CALDAS       MARMATO  5.49 -75.60
# 69       2010-12-05  ANTIOQUIA         BELLO  6.36 -75.59
# 253      2014-05-26     TOLIMA        HERVEO  5.07 -75.24
# 473      2020-03-14  SANTANDER   BUCARAMANGA  7.16 -73.11
# ..              ...        ...           ...   ...    ...
# 474      2020-04-16     NARIÑO  LA UNION (N)  1.62 -77.14
# 55       2010-11-22     CALDAS   PENSILVANIA  5.39 -75.11
# 472      2020-02-29     NARIÑO       IPIALES  0.50 -77.24
# 18       2010-07-17  SANTANDER     BARICHARA  6.65 -73.21
# 36       2010-11-07     BOYACA       OTANCHE  5.75 -74.20
#
#      Confidence ratio (km)  Deaths         Trigger       Source  \
# 252                   1.24       1         Unknown        UNGRD
# 257                   3.40       1  Human activity          ANM
# 69                    6.87      82        Rainfall        UNGRD
# 253                  10.14       1         Unknown        UNGRD
# 473                   6.99       1        Rainfall        UNGRD
# ..                     ...     ...             ...          ...
# 474                   6.73       1         Unknown        UNGRD
# 55                    0.76       5        Rainfall        UNGRD
# 472                  22.45       1        Rainfall        UNGRD
# 18                    6.62       2         Unknown        UNGRD
# 36                   12.30       6        Rainfall  DESINVENTAR
#
#      Rain Yesterday  Rain Today
# 252             8.0        19.7
# 257             0.0         0.0
# 69             19.3        19.1
# 253             0.0         2.0
# 473             8.2        11.6
# ..              ...         ...
# 474             2.2         4.6
# 55              3.1         4.9
# 472             4.9         0.3
# 18              8.4         9.4
# 36             17.8         2.8
#
# [504 rows x 11 columns]

# %%
dates = []
first_date = datetime.strptime("2010-01-01", "%Y-%m-%d")

for i, row in random_sample.iterrows():
    time_delta = row["Occurrence Date"] - first_date
    random_delta = np.random.randint(0, time_delta.days)
    random_date = first_date + pd.Timedelta(days = random_delta)
    dates.append(random_date)
    
random_sample["Occurrence Date"] = dates
random_sample["Deaths"] = 0
random_sample["Trigger"] = "N/A"
random_sample.reset_index(drop = True, inplace = True)

random_sample
# Out:
#     Occurrence Date Department  Municipality   Lat   Long  \
# 0        2011-03-03      HUILA         SUAZA  1.94 -75.80
# 1        2013-03-03     CALDAS       MARMATO  5.49 -75.60
# 2        2010-05-13  ANTIOQUIA         BELLO  6.36 -75.59
# 3        2013-01-28     TOLIMA        HERVEO  5.07 -75.24
# 4        2010-06-19  SANTANDER   BUCARAMANGA  7.16 -73.11
# ..              ...        ...           ...   ...    ...
# 499      2012-02-09     NARIÑO  LA UNION (N)  1.62 -77.14
# 500      2010-06-18     CALDAS   PENSILVANIA  5.39 -75.11
# 501      2013-11-23     NARIÑO       IPIALES  0.50 -77.24
# 502      2010-05-15  SANTANDER     BARICHARA  6.65 -73.21
# 503      2010-05-19     BOYACA       OTANCHE  5.75 -74.20
#
#      Confidence ratio (km)  Deaths Trigger       Source  Rain Yesterday  \
# 0                     1.24       0     N/A        UNGRD             8.0
# 1                     3.40       0     N/A          ANM             0.0
# 2                     6.87       0     N/A        UNGRD            19.3
# 3                    10.14       0     N/A        UNGRD             0.0
# 4                     6.99       0     N/A        UNGRD             8.2
# ..                     ...     ...     ...          ...             ...
# 499                   6.73       0     N/A        UNGRD             2.2
# 500                   0.76       0     N/A        UNGRD             3.1
# 501                  22.45       0     N/A        UNGRD             4.9
# 502                   6.62       0     N/A        UNGRD             8.4
# 503                  12.30       0     N/A  DESINVENTAR            17.8
#
#      Rain Today
# 0          19.7
# 1           0.0
# 2          19.1
# 3           2.0
# 4          11.6
# ..          ...
# 499         4.6
# 500         4.9
# 501         0.3
# 502         9.4
# 503         2.8
#
# [504 rows x 11 columns]

# %%
rain_yesterday = []
rain_today = []

for i, row in random_sample.iterrows():
    start_date = (row["Occurrence Date"] + pd.Timedelta(days=-1)).strftime("%Y-%m-%d")
    end_date = row["Occurrence Date"].strftime("%Y-%m-%d")

    endpoint = "{}/timeline/{},{}/{}/{}".format(
        os.environ.get("WEATHER_URL"),
        row["Lat"],
        row["Long"],
        start_date,
        end_date
    )
    
    params = {
        "unitGroup": "metric",
        "key": os.environ.get("WEATHER_API_KEY")
    }
    
    response = requests.get(endpoint, params)
    result = json.loads(response.text)
    
    rain_yesterday.append(result["days"][0]["precip"])
    rain_today.append(result["days"][1]["precip"])
    
random_sample["Rain Yesterday"] = rain_yesterday
random_sample["Rain Today"] = rain_today

display(random_sample.describe())
random_sample
# Out:
#                      Occurrence Date         Lat        Long  \
# count                            504  504.000000  504.000000
# mean   2012-05-16 21:45:42.857143040    4.966171  -75.221706
# min              2010-01-01 00:00:00    0.500000  -78.370000
# 25%              2010-06-26 00:00:00    3.097500  -76.010000
# 50%              2011-05-30 00:00:00    5.120000  -75.490000
# 75%              2013-10-06 12:00:00    6.502500  -74.270000
# max              2019-09-11 00:00:00   11.120000  -68.010000
# std                              NaN    2.193032    1.407167
#
#        Confidence ratio (km)  Deaths  Rain Yesterday  Rain Today
# count             504.000000   504.0      504.000000  504.000000
# mean                9.305377     0.0        5.319643    4.932540
# min                 0.100000     0.0        0.000000    0.000000
# 25%                 4.655000     0.0        0.100000    0.000000
# 50%                 7.870000     0.0        2.200000    2.100000
# 75%                12.410000     0.0        6.500000    7.025000
# max                73.090000     0.0      112.000000   53.400000
# std                 7.874268     0.0        8.971585    7.223408
#     Occurrence Date Department  Municipality   Lat   Long  \
# 0        2011-03-03      HUILA         SUAZA  1.94 -75.80
# 1        2013-03-03     CALDAS       MARMATO  5.49 -75.60
# 2        2010-05-13  ANTIOQUIA         BELLO  6.36 -75.59
# 3        2013-01-28     TOLIMA        HERVEO  5.07 -75.24
# 4        2010-06-19  SANTANDER   BUCARAMANGA  7.16 -73.11
# ..              ...        ...           ...   ...    ...
# 499      2012-02-09     NARIÑO  LA UNION (N)  1.62 -77.14
# 500      2010-06-18     CALDAS   PENSILVANIA  5.39 -75.11
# 501      2013-11-23     NARIÑO       IPIALES  0.50 -77.24
# 502      2010-05-15  SANTANDER     BARICHARA  6.65 -73.21
# 503      2010-05-19     BOYACA       OTANCHE  5.75 -74.20
#
#      Confidence ratio (km)  Deaths Trigger       Source  Rain Yesterday  \
# 0                     1.24       0     N/A        UNGRD             9.5
# 1                     3.40       0     N/A          ANM             0.0
# 2                     6.87       0     N/A        UNGRD             0.2
# 3                    10.14       0     N/A        UNGRD             0.0
# 4                     6.99       0     N/A        UNGRD            24.5
# ..                     ...     ...     ...          ...             ...
# 499                   6.73       0     N/A        UNGRD            19.7
# 500                   0.76       0     N/A        UNGRD             1.6
# 501                  22.45       0     N/A        UNGRD             1.6
# 502                   6.62       0     N/A        UNGRD             0.1
# 503                  12.30       0     N/A  DESINVENTAR             5.5
#
#      Rain Today
# 0           0.2
# 1           0.9
# 2           0.4
# 3           0.0
# 4          12.7
# ..          ...
# 499         0.0
# 500        11.0
# 501         2.1
# 502         3.7
# 503         9.0
#
# [504 rows x 11 columns]

# %%
landslides_recent["Landslide"] = 1
random_sample["Landslide"] = 0

df_final = pd.concat([landslides_recent, random_sample]).reset_index(drop = True)

display(df_final.groupby("Landslide")[["Rain Yesterday", "Rain Today"]].describe())
df_final
# Out:
#           Rain Yesterday                                                     \
#                    count      mean        std  min  25%  50%     75%    max
# Landslide
# 0                  504.0  5.319643   8.971585  0.0  0.1  2.2   6.500  112.0
# 1                  504.0  8.609921  11.012548  0.0  1.3  5.1  11.825   88.1
#
#           Rain Today
#                count     mean        std  min  25%  50%     75%   max
# Landslide
# 0              504.0  4.93254   7.223408  0.0  0.0  2.1   7.025  53.4
# 1              504.0  8.69881  10.544394  0.0  1.6  5.3  11.600  89.1
#      Occurrence Date       Department  Municipality   Lat   Long  \
# 0         2010-01-10           BOGOTA        BOGOTA  4.63 -74.11
# 1         2010-02-25     CUNDINAMARCA       VILLETA  5.01 -74.49
# 2         2010-04-10           TOLIMA        HERVEO  5.11 -75.19
# 3         2010-04-10  VALLE DEL CAUCA          CALI  3.40 -76.58
# 4         2010-04-29           BOGOTA        BOGOTA  4.63 -74.11
# ...              ...              ...           ...   ...    ...
# 1003      2012-02-09           NARIÑO  LA UNION (N)  1.62 -77.14
# 1004      2010-06-18           CALDAS   PENSILVANIA  5.39 -75.11
# 1005      2013-11-23           NARIÑO       IPIALES  0.50 -77.24
# 1006      2010-05-15        SANTANDER     BARICHARA  6.65 -73.21
# 1007      2010-05-19           BOYACA       OTANCHE  5.75 -74.20
#
#       Confidence ratio (km)  Deaths   Trigger       Source  Rain Yesterday  \
# 0                     11.60       1   Unknown          HEB             0.0
# 1                      6.70       1  Rainfall        UNGRD             2.2
# 2                      1.52       1   Unknown        UNGRD             4.9
# 3                     13.44       1   Unknown        UNGRD            10.1
# 4                     11.60       1   Unknown        UNGRD             4.4
# ...                     ...     ...       ...          ...             ...
# 1003                   6.73       0       N/A        UNGRD            19.7
# 1004                   0.76       0       N/A        UNGRD             1.6
# 1005                  22.45       0       N/A        UNGRD             1.6
# 1006                   6.62       0       N/A        UNGRD             0.1
# 1007                  12.30       0       N/A  DESINVENTAR             5.5
#
#       Rain Today  Landslide
# 0            0.0          1
# 1            9.7          1
# 2           18.0          1
# 3           23.1          1
# 4           16.3          1
# ...          ...        ...
# 1003         0.0          0
# 1004        11.0          0
# 1005         2.1          0
# 1006         3.7          0
# 1007         9.0          0
#
# [1008 rows x 12 columns]

# %%
df_final.to_csv("../datasets/rainfall.csv", index = False, quoting = False)
